# %% [markdown]
# # Importing data

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/drive/MyDrive/data set/sales(2).csv')
# Out:
# <ipython-input-6-6619338ed86a>:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/data set/sales(2).csv')

# %% [markdown]
# #Exploring Data

# %%
df.head()

# %%
print(df.shape)
# Out:
# (286392, 36)

# %%
print("Missing values")
print(df.isnull().sum())
# Out:
# Missing values
# order_id            0
# order_date          0
# status              0
# item_id             0
# sku                 0
# qty_ordered         0
# price               0
# value               0
# discount_amount     0
# total               0
# category            0
# payment_method      0
# bi_st               0
# cust_id             0
# year                0
# month               0
# ref_num             0
# Name Prefix         0
# First Name          0
# Middle Initial      0
# Last Name           0
# Gender              0
# age                 0
# full_name           0
# E Mail              0
# Customer Since      0
# SSN                 0
# Phone No.           0
# Place Name          0
# County              0
# City                0
# State               0
# Zip                 0
# Region              0
# User Name           0
# Discount_Percent    0
# dtype: int64

# %% [markdown]
# #Data Cleaning

# %%
df.drop_duplicates(subset='order_id', inplace=True)

# %%
print(df.shape)
# Out:
# (201716, 36)

# %% [markdown]
# 286392 --> 201716 (removed duplicate order ID)

# %%
to_remove = ["sku","bi_st","Name Prefix","First Name","Middle Initial","Last Name","full_name","E Mail", "SSN", "Place Name",
             "County", "City", "Zip", "User Name", "Phone No. "]
df.drop(columns= to_remove, axis=1, inplace=True)

# %%
print(df.shape)
# Out:
# (201716, 20)

# %% [markdown]
# 36 --> 20 (removed columns not in use)

# %% [markdown]
# # Download cleaned CSV

# %%
# Save DataFrame to a CSV file
df.to_csv('cleaned.csv', index=False)

# Download the CSV file to your local machine
from google.colab import files
files.download('cleaned.csv')
